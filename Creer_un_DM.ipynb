# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
#def generate_missing_data(df, rate):
  # Calculer le nombre de données manquantes
    nb_manquants = int(rate * df.shape[0] * df.shape[1])
  # Générer des indices aléatoires pour les données manquantes
    indices_manquants = np.random.choice(df.shape[0] * df.shape[1], nb_manquants, replace=False)
  # Remplacer les données manquantes par NaN
    for indice in indices_manquants:
        i = indice // df.shape[1]
        j = indice % df.shape[1]
        df.iloc[i, j] = float("NaN")
    return df
# Initialiser le DataFrame
df =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/2018-2022_paludisme_SP.csv")
# Générer des données manquantes
#df_with_missing_data = generate_missing_data(df, 0.05)
# Afficher le DataFrame avec des données manquantes
#print(df_with_missing_data)
# Out:
#   File "C:\Users\Bag's\AppData\Local\Temp\ipykernel_6268\2157885351.py", line 3
#     nb_manquants = int(rate * df.shape[0] * df.shape[1])
#     ^
# IndentationError: unexpected indent

# %%
nb_nan = df_with_missing_data.isna().sum().sum()
print(nb_nan)
# Out:
# 143

# %%
#df_with_missing_data.to_csv("C:/Users/Bag's/Downloads/donnees/projet2/5%/DM_5_2018-2022_paludisme_SP.csv", index=False)

# %%
#df5 =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/20%/DM_20_2018-2022_paludisme_SP.csv")
#df5

# %%
#dfw18 =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/date/DATE_2018.csv")
#dfw18.head()

# %%
#dfw19 =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/date/DATE_2019.csv")
#dfw19

# %%
# Concatenate the sum to the last row
#concte1= dfw18.append(dfw19)
#concte1

# %%
#dfw20 =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/date/DATE_2020.csv")
#dfw20

# %%
# Concatenate the sum to the last row
#concte2= concte1.append(dfw20)
#concte2

# %%
#dfw21 =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/date/DATE_2021.csv")
#dfw21

# %%
# Concatenate the sum to the last row
#concte3= concte2.append(dfw21)
#concte3

# %%
#dfw22 =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/date/DATE_2022.csv")
#dfw22

# %%
# Concatenate the sum to the last row
#concte4= concte3.append(dfw22)
#concte4

# %%
#concte4.to_csv("C:/Users/Bag's/Downloads/donnees/projet2/date/2018-2022.csv", index=False)

# %%
dfw =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/5%/DM_5_2018-2022_paludisme_SP.csv")
dfw
# Out:
#      Bankim  Banyo  Belel   Dang  Djohong  Meiganga  Ngaoundal  \
# 0     177.0  154.0  120.0   93.0    156.0     320.0        NaN
# 1     143.0  143.0  175.0  134.0    174.0     283.0      206.0
# 2     163.0  166.0  147.0  108.0    208.0     227.0      211.0
# 3     136.0  136.0  118.0  122.0    167.0     210.0      220.0
# 4     122.0  144.0  134.0    NaN    201.0     204.0      184.0
# ..      ...    ...    ...    ...      ...       ...        ...
# 255   187.0    NaN   88.0  205.0    158.0     375.0      263.0
# 256   164.0  167.0  104.0  201.0    132.0     369.0      200.0
# 257   171.0  186.0   88.0  217.0     83.0     339.0      194.0
# 258   170.0    NaN   77.0  178.0     84.0     333.0      173.0
# 259   190.0  144.0   81.0  163.0     85.0     344.0      189.0
#
#      Ngaoundere_Rural  Ngaoundere_Urbain  Tibati  Tignere
# 0               306.0              536.0   180.0    176.0
# 1               266.0                NaN   182.0    193.0
# ...

# %%
dfw1 =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/date/2018-2022.csv")

# %%
Concat= pd.concat([dfw1, dfw], axis=1)
#Concat

# %%
Concat.to_csv("C:/Users/Bag's/Downloads/donnees/projet2/5%/DM_5_2018-2022_paludisme_P.csv", index=False)

# %%
fw =pd.read_csv("C:/Users/Bag's/Downloads/donnees/projet2/5%/DM_5_2018-2022_paludisme_P.csv")
fw
# Out:
#        periodid  Bankim  Banyo  Belel   Dang  Djohong  Meiganga  Ngaoundal  \
# 0    2018-01-07   177.0  154.0  120.0   93.0    156.0     320.0        NaN
# 1    2018-01-14   143.0  143.0  175.0  134.0    174.0     283.0      206.0
# 2    2018-01-21   163.0  166.0  147.0  108.0    208.0     227.0      211.0
# 3    2018-01-28   136.0  136.0  118.0  122.0    167.0     210.0      220.0
# 4    2018-02-04   122.0  144.0  134.0    NaN    201.0     204.0      184.0
# ..          ...     ...    ...    ...    ...      ...       ...        ...
# 255  2022-11-27   187.0    NaN   88.0  205.0    158.0     375.0      263.0
# 256  2022-12-04   164.0  167.0  104.0  201.0    132.0     369.0      200.0
# 257  2022-12-11   171.0  186.0   88.0  217.0     83.0     339.0      194.0
# 258  2022-12-18   170.0    NaN   77.0  178.0     84.0     333.0      173.0
# 259  2022-12-25   190.0  144.0   81.0  163.0     85.0     344.0      189.0
#
#      Ngaoundere_Rural  Ngaoundere_Urbain  Tibati  Tignere
# ...
